# %%
#Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import scipy.stats as st
from scipy.stats import linregress
import hvplot.pandas
from pprint import pprint

#Import API keys
from config import geoapify_key

# %%
#Reading csv
demo_path = "Resources/state_demographics.csv"
demo_df = pd.read_csv(demo_path)
demo_df.head()
# Out:
#                   State  Population.Population Percent Change  \
# 0           Connecticut                                 -10.2
# 1              Delaware                                   8.4
# 2  District of Columbia                                  17.3
# 3               Florida                                  14.2
# 4               Georgia                                   9.6
#
#    Population.2014 Population  Population.2010 Population  \
# 0                     3605944                     3574097
# 1                      989948                      897934
# 2                      689545                      601723
# 3                    21538187                    18801310
# 4                    10711908                     9687653
#
#    Age.Percent Under 5 Years  Age.Percent Under 18 Years  \
# 0                        5.1                        20.4
# 1                        5.6                        20.9
# 2                        6.4                        18.2
# ...

# %%
#Dropping irrelevant columns
demo_df = demo_df.drop(columns=['Population.2010 Population','Miscellaneous.Percent Female',
                               'Ethnicities.White Alone', 'Ethnicities.Black Alone', 'Ethnicities.American Indian and Alaska Native Alone',
 'Ethnicities.Asian Alone',
 'Ethnicities.Native Hawaiian and Other Pacific Islander Alone',
 'Ethnicities.Two or More Races',
 'Ethnicities.Hispanic or Latino',
 'Ethnicities.White Alone, not Hispanic or Latino',
 'Miscellaneous.Veterans',
 'Miscellaneous.Foreign Born',
 'Housing.Housing Units',
 'Housing.Homeownership Rate',
 'Housing.Median Value of Owner-Occupied Units',
 'Housing.Households',
 'Housing.Persons per Household',
 'Miscellaneous.Living in Same House +1 Years',
 'Miscellaneous.Language Other than English at Home',
 'Housing.Households with a computer',
 'Housing.Households with a Internet',
 'Education.High School or Higher',
 "Education.Bachelor's Degree or Higher",
 'Miscellaneous.Percent Under 66 Years With a Disability',
 'Miscellaneous.Percent Under 65 Years Witout Health insurance',
 'Sales.Accommodation and Food Services Sales',
 'Miscellaneous.Manufacturers Shipments',
 'Sales.Retail Sales',
 'Miscellaneous.Mean Travel Time to Work','Income.Persons Below Poverty Level',
 'Employment.Nonemployer Establishments',
 'Employment.Firms.Total',
 'Employment.Firms.Men-Owned',
 'Employment.Firms.Women-Owned',
 'Employment.Firms.Minority-Owned',
 'Employment.Firms.Nonminority-Owned',
 'Employment.Firms.Veteran-Owned',
 'Employment.Firms.Nonveteran-Owned','Miscellaneous.Land Area'])
demo_df.head()
# Out:
#                   State  Population.Population Percent Change  \
# 0           Connecticut                                 -10.2
# 1              Delaware                                   8.4
# 2  District of Columbia                                  17.3
# 3               Florida                                  14.2
# 4               Georgia                                   9.6
#
#    Population.2014 Population  Age.Percent Under 5 Years  \
# 0                     3605944                        5.1
# 1                      989948                        5.6
# 2                      689545                        6.4
# 3                    21538187                        5.3
# 4                    10711908                        6.2
#
#    Age.Percent Under 18 Years  Age.Percent 65 and Older  \
# 0                        20.4                      17.7
# 1                        20.9                      19.4
# 2                        18.2                      12.4
# ...

# %%
#Renaming columns name
demo_df = demo_df.rename(columns={'Population.Population Percent Change':'Population Percent Change',
                                  'Population.2014 Population':'population', 
                                  'Age.Percent Under 5 Years':'% age under 5', 
                                  'Age.Percent Under 18 Years':'% age under 18',
                                  'Age.Percent 65 and Older': '% age 65 and older',
                                  'Income.Median Houseold Income': "median household income",
                                  'Income.Per Capita Income': 'per capita income',
                                  'Population.Population per Square Mile': 'population per square mile'})
demo_df.head()
# Out:
#                   State  Population Percent Change  population  % age under 5  \
# 0           Connecticut                      -10.2     3605944            5.1
# 1              Delaware                        8.4      989948            5.6
# 2  District of Columbia                       17.3      689545            6.4
# 3               Florida                       14.2    21538187            5.3
# 4               Georgia                        9.6    10711908            6.2
#
#    % age under 18  % age 65 and older  median household income  \
# 0            20.4                17.7                    78444
# 1            20.9                19.4                    68287
# 2            18.2                12.4                    86420
# 3            19.7                20.9                    55660
# 4            23.6                14.3                    58700
#
#    per capita income  population per square mile
# 0              44496                       738.1
# ...

# %%
#Renaming state in state column
demo_df = demo_df.replace({'Alabama': 'AL',
    'Montana': 'MT',
    'Alaska': 'AK',
    'Nebraska': 'NE',
    'Arizona': 'AZ',
    'Nevada': 'NV',
    'Arkansas': 'AR',
    'New Hampshire': 'NH',
    'California': 'CA',
    'New Jersey': 'NJ',
    'Colorado': 'CO',
    'New Mexico': 'NM',
    'Connecticut': 'CT',
    'New York': 'NY',
    'Delaware': 'DE',
    'North Carolina': 'NC',
    'Florida': 'FL',
    'North Dakota': 'ND',
    'Georgia': 'GA',
    'Ohio': 'OH',
    'Hawaii': 'HI',
    'Oklahoma': 'OK',
    'Idaho': 'ID',
    'Oregon': 'OR',
    'Illinois': 'IL',
    'Pennsylvania': 'PA',
    'Indiana': 'IN',
    'Rhode Island': 'RI',
    'Iowa': 'IA',
    'South Carolina': 'SC',
    'Kansas': 'KS',
    'South Dakota': 'SD',
    'Kentucky': 'KY',
    'Tennessee': 'TN',
    'Louisiana': 'LA',
    'Texas': 'TX',
    'Maine': 'ME',
    'Utah': 'UT',
    'Maryland': 'MD',
    'Vermont': 'VT',
    'Massachusetts': 'MA',
    'Virginia': 'VA',
    'Michigan': 'MI',
    'Washington': 'WA',
    'Minnesota': 'MN',
    'West Virginia': 'WV',
    'Mississippi': 'MS',
    'Wisconsin': 'WI',
    'Missouri': 'MO',
    'Wyoming': 'WY',
    'District of Columbia': 'DC'})
demo_df.head()
# Out:
#   State  Population Percent Change  population  % age under 5  % age under 18  \
# 0    CT                      -10.2     3605944            5.1            20.4
# 1    DE                        8.4      989948            5.6            20.9
# 2    DC                       17.3      689545            6.4            18.2
# 3    FL                       14.2    21538187            5.3            19.7
# 4    GA                        9.6    10711908            6.2            23.6
#
#    % age 65 and older  median household income  per capita income  \
# 0                17.7                    78444              44496
# 1                19.4                    68287              35450
# 2                12.4                    86420              56147
# 3                20.9                    55660              31619
# 4                14.3                    58700              31067
#
#    population per square mile
# 0                       738.1
# 1                       460.8
# ...

# %%
#read csv
food_path = 'Resources/FastFoodRestaurants.csv'
food_db = pd.read_csv(food_path)
food_db.head()
# Out:
#                  address                    city country  \
# 0            324 Main St                 Massena      US
# 1        530 Clinton Ave  Washington Court House      US
# 2   408 Market Square Dr               Maysville      US
# 3  6098 State Highway 37                 Massena      US
# 4        139 Columbus Rd                  Athens      US
#
#                                                 keys  latitude  longitude  \
# 0                us/ny/massena/324mainst/-1161002137  44.92130  -74.89021
# 1  us/oh/washingtoncourthouse/530clintonave/-7914...  39.53255  -83.44526
# 2       us/ky/maysville/408marketsquaredr/1051460804  38.62736  -83.79141
# 3       us/ny/massena/6098statehighway37/-1161002137  44.95008  -74.84553
# 4               us/oh/athens/139columbusrd/990890980  39.35155  -82.09728
#
#                name postalCode province  \
# 0        McDonald's      13662       NY
# 1           Wendy's      43160       OH
# 2  Frisch's Big Boy      41056       KY
# ...

# %%
#Count how many unique resturant names
count = food_db['name'].nunique()
count
# Out:
# 548

# %%
#Dropping irrelevant columns
food_db = food_db.drop(columns=['websites', 'keys', 'country'])
food_db.head()
# Out:
#                  address                    city  latitude  longitude  \
# 0            324 Main St                 Massena  44.92130  -74.89021
# 1        530 Clinton Ave  Washington Court House  39.53255  -83.44526
# 2   408 Market Square Dr               Maysville  38.62736  -83.79141
# 3  6098 State Highway 37                 Massena  44.95008  -74.84553
# 4        139 Columbus Rd                  Athens  39.35155  -82.09728
#
#                name postalCode province
# 0        McDonald's      13662       NY
# 1           Wendy's      43160       OH
# 2  Frisch's Big Boy      41056       KY
# 3        McDonald's      13662       NY
# 4   OMG! Rotisserie      45701       OH

# %%
#Renaming columns
food_db = food_db.rename(columns={'province':'State', 'postalCode':'postal_code', 'name':'restaurant'})
food_db.head()
# Out:
#                  address                    city  latitude  longitude  \
# 0            324 Main St                 Massena  44.92130  -74.89021
# 1        530 Clinton Ave  Washington Court House  39.53255  -83.44526
# 2   408 Market Square Dr               Maysville  38.62736  -83.79141
# 3  6098 State Highway 37                 Massena  44.95008  -74.84553
# 4        139 Columbus Rd                  Athens  39.35155  -82.09728
#
#          restaurant postal_code State
# 0        McDonald's       13662    NY
# 1           Wendy's       43160    OH
# 2  Frisch's Big Boy       41056    KY
# 3        McDonald's       13662    NY
# 4   OMG! Rotisserie       45701    OH

# %%
#Combining Colorado Spring with Colorado
food_db = food_db.replace({'Co Spgs':'CO'})
food_db.head()
# Out:
#                  address                    city  latitude  longitude  \
# 0            324 Main St                 Massena  44.92130  -74.89021
# 1        530 Clinton Ave  Washington Court House  39.53255  -83.44526
# 2   408 Market Square Dr               Maysville  38.62736  -83.79141
# 3  6098 State Highway 37                 Massena  44.95008  -74.84553
# 4        139 Columbus Rd                  Athens  39.35155  -82.09728
#
#          restaurant postal_code State
# 0        McDonald's       13662    NY
# 1           Wendy's       43160    OH
# 2  Frisch's Big Boy       41056    KY
# 3        McDonald's       13662    NY
# 4   OMG! Rotisserie       45701    OH

# %%
# def replace_value(name):
#     if name in ['A & W Family Restaurant', 'A&W All American Food','A&W All-American Food', 
#                 'A&W All-American Foods','A&W Restaurant', 'A&W/Long John Silvers','A&w','A&w Restaurant','Aw Restaurant']:
#         return 'A&W'
    
#     else:
#         return name

# %%
# food_db['restaurant'] = food_db['restaurant'].apply(lambda x: replace_value(x))
# food_db['restaurant']

# %%
# food_db[food_db['restaurant'] == 'A & W Family Restaurant']

# %%
#Combining all similar restaurant name
#A&W
food_db['restaurant'] = food_db['restaurant'].replace(to_replace={'A & W Family Restaurant', 
                                                                  'A&W All American Food',
                                                                  'A&W All-American Food', 
                                                                  'A&W All-American Foods',
                                                                  'A&W Restaurant', 
                                                                  'A&W/Long John Silvers', 
                                                                  'A&w', 
                                                                  'A&w Restaurant',
                                                                  'Aw Restaurant'}, value='A&W')
#McDonalds
food_db['restaurant'] = food_db['restaurant'].replace(to_replace={"Mc Donald's", 
                                                                  'Mc Donalds', 
                                                                  "McDonald's",
                                                                  "McDonald's of Mililani Mauka",
                                                                  'McDonalds @ Old Atlanta', 
                                                                  'McDonald’s',
                                                                  "Mcalister's Deli", 
                                                                  "Mcdonald's", 
                                                                  "Mcdonald's #25557",
                                                                  "Mcdonald's - Walmart", 
                                                                  'Mcdonalds'}, value="McDonalds")
#Arby's
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Arby's",
                                                                 "Arbys",
                                                                 "Arby's Antigo"}, value="Arby's")
#Barckyard Burgers
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Back Yard Burgers"}, value="Barckyard Burgers")

#Baja Fresh
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Baja Fresh Mexican Grill"}, value="Baja Fresh")

#B.Good
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"B. Good", 
                                                                 "b.good"}, value="B.Good")

#Blake's LotaBurger
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Blakes Lotaburger", 
                                                                 "Blake's Lotaburger"}, value="Blake's LotaBurger")

#Bob Evans
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Bob Evans Restaurant"}, value="Bob Evans")

#Blimpie
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"BLIMPIE", 
                                                                 "Blimpie Subs & Sandwiches"}, value="Blimpie")

#Boston Market
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Boston Chowda Company", 
                                                                 "Boston Market 381"}, value="Boston Market")
#Barum's
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Braum's Ice Cream & Dairy Store"}, value="Braum's") 

#Burger King
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Burger King Salou", 
                                                                 "Burger Time", 
                                                                 "Burger's Landing", 
                                                                 "Burgerville", 
                                                                 "Burgerville, USA",
                                                                 "B K"}, value="Burger King")

#Carl's Jr
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Carl's / Green Burrito",
                                                                 "Carl's Jr - Green Burrito",
                                                                 "Carl's Jr / Green Burrito", 
                                                                 "Carl's Jr.",
                                                                 "Carl's Jr. / Green Burrito", 
                                                                 "Carls Jr",
                                                                 "Carls Jr. / Green Burrito"}, value="Carl's Jr")
#Checkers
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Checker's", 
                                                                 "Checkers Burgers and Fries", 
                                                                 "Checker's Hamburgers", 
                                                                 "Checker's Drive-in Restaurant", 
                                                                 "Checkers Drive-in Restaurant", 
                                                                 "Checkers Hamburgers"}, value="Checkers")

#Chick-Fil-A
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Chick-fil-A", 
                                      "Chick-fil-a Superstition Springs Center", 
                                      "Chick-fil-a Orange Avenue", 
                                      "Chick-fil-a Truett's Luau", 
                                      "Chick-fil-a Magnolia Mall", 
                                      "Chick-fil-a"}, value="Chick-Fil-A")

#Cook Out
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Cook-Out", 
                                                                 "Cookout"}, value="Cook Out")

#Costa Vida
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Costa Vida Fresh Mexican Grill"}, value="Costa Vida")

#Cousins Subs
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Cousins Subs of Green Bay - Oneida St. & Ramada Way"
                                                                }, value="Cousins Subs")

#Culver's
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Culvers"}, value="Culver's")

#D'Angelo
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"D'Angelo Grilled Sandwiches", 
                                                                 "D'angelo Grilled Sandwiches"}, value="D'Angelo")

#DQ Grill & Chill
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"DQ Grill & Chill / Orange Julius", 
                                                                 "Dairy Queen Grill & Chill / Orange Julius", 
                                                                 "Dairy Queen Grill & Chill", 
                                                                 "Dq Grill & Chill"}, value="DQ Grill & Chill")

#Domino's Pizza
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Dominos Pizza"}, value="Domino's Pizza")

#Dunkin' Donuts
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Dunkin Donuts"}, value="Dunkin' Donuts")

#Fosters Freeze
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Foster's Freeze"}, value="Fosters Freeze")

#Great Steak
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Great Steak & Potato Co", 
                                                                 "Great Steak And Potato Co"}, value="Great Steak")

#Jack in the Box
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Jack's", 
                                                                 "Jack In The Box"}, value="Jack in the Box")

#Jimmy John's
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Jimmy John's Gourmet Sandwiches", 
                                                                 "Jimmy Johns"}, value="Jimmy John's")

#KFC
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"KFC - Kentucky Fried Chicken", 
                                                                 "KFC / A&W", "KFC / Taco Bell", 
                                                                 "Kfc", 
                                                                 "Kfc - Kentucky Fried Chicken", 
                                                                 "KFC/Taco Bell", 
                                                                 "Kentucky Fried Chicken",
                                                                 'KFC - KFC'}, value="KFC")

#Long John Silver's
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Long John Silver/ A&W", 
                                                                 "Long John Silver's / A&W", 
                                                                 "Long John Silvers", 
                                                                 "Long John Silvers / A&W"}, value="Long John Silver's")

#Papa Johns Pizza
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Papa John's", 
                                                                 "Papa John's Pizza", 
                                                                 "Papa Johns", 
                                                                 "Papa John’s Pizza", 
                                                                 "Papa Johns Pizza Pizza" }, value="Papa Johns Pizza")

#Panda Express
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Panda"}, value="Panda Express")

#Popeyes
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Popeye's", 
                                                                 "Popeyes Chicken & Biscuits", 
                                                                 "Popeyes Chicken and Biscuits",  
                                                                 "Popeyes Louisiana Kitchen",
                                                                 "Popeye's Chicken", 
                                                                 "Popeye's Chicken & Biscuits",
                                                                 "Popeye's Louisiana Kitchen"}, value="Popeyes")

#Port of Subs
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Port Of Subs"}, value="Port of Subs")

#QDOBA Mexican Eats
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Qdoba Mexican Eats", 
                                                                 "Qdoba Mexican Grill"}, value="QDOBA Mexican Eats")

#Quiznos
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Quiznos Sub", 
                                                                 "Quizno's +"}, value="Quiznos")

#Rally's
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Rally's Hamburgers", 
                                                                 "Rally's Springfield"}, value="Rally's")

#Raising Cane's
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Raising Cane's Chicken Fingers"}, value="Raising Cane's")

#SONIC
food_db['restaurant'] = food_db['restaurant'].replace(to_replace={'Sonic Drive In', 
                                                                  'Sonic Drive in', 
                                                                  'Sonic Drive-In',
                                                                  'Sonic Drive-in', 
                                                                  'Sonic Drive-in (trailer)',
                                                                  'SONIC Drive In', 
                                                                  'SONIC Drive-In'}, value="Sonic")
#SUBWAY
food_db['restaurant']= food_db['restaurant'].replace(to_replace={'SUBWAY',
                                                                 'SUBWAY®',
                                                                 'Subway (johnson) @ Jonesboro', 
                                                                 "Subway - Bell's Ferry",
                                                                 'Subway - Roland Park', 
                                                                 'Subway Citgo of Quarryville',
                                                                 'Subway Guitars', 
                                                                 'Subway Sandwiches',
                                                                 'Subway Sandwiches and Salads'}, value="Subway")

#Steak 'n Shake
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Steak N Shake", 
                                                                 "Steak 'N Shake", 
                                                                 "Steak Escape",
                                                                 "Steak-out"}, value="Steak 'n Shake")

#Taco Bell
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Taco Bell/Pizza Hut Express",
                                                                 'Taco Bueno',
                                                                 'Taco Cabana', 
                                                                 'Taco Casa', 
                                                                 'Taco Del Mar', 
                                                                 'Taco Delight',
                                                                 "Taco John's", 
                                                                 'Taco Local', 
                                                                 'Taco Mayo', 
                                                                 'Taco Time',
                                                                 'Taco del Mar', 
                                                                 'TacoTime'}, value="Taco Bell")

#Toppers
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Toppers Pizza", 
                                                                 "Topper's Pizza", 
                                                                 "Toppers Express"}, value="Toppers")

#Wendy's
food_db['restaurant']= food_db['restaurant'].replace(to_replace={"Wendys", 
                                                                 "Wendy Two Two Eight"}, value="Wendy's")

# %%
#Sorting by alphabetical order and listing the restaurant
sort = food_db.sort_values('restaurant')
sort['restaurant'].unique()
# Out:
# array(['11-Jul', '31st Avenue Gyro', '7-Eleven', 'A&W',
#        "AJ's Hotdogs & Gyros", "Alice's", 'Ama Ristorante',
#        'Amigos/Kings Classic', 'Aprisa Mexican Cuisine', "Arby's",
#        'Arctic Circle', 'Au Bon Pain', "Auntie Anne's",
#        'B Z Breakfast Burgers Beyond', 'B.Good', 'BGR - The Burger Joint',
#        "BIG & little's Restaurant", 'Backyard Burgers',
#        'Bad Daddys Burger Bar', 'Baja Fresh', "Baker's Drive Thru",
#        'Ball State Lafollette Dining', 'Bamboo Bistro',
#        'Barckyard Burgers', 'Baskin-Robbins', 'Bb&t', "Ben & Jerry's",
#        'Bills Place', "Blake's LotaBurger", 'Blimpie', 'Blondies',
#        'Bob Evans', "Bobby's Burger Palace",
#        "Bojangles' Famous Chicken 'n Biscuits", 'Boston Market',
#        "Braum's", 'Bravo Tacos', 'Breadeaux Pizza', "Brixton's",
#        'Buds Chicken & Seafood', 'Burger King', "Bush's Chicken",
#        'Cafe Rio', "Capriotti's Sandwich Shop", "Capt Crab's Take-Away",
# ...

# %%
#Merging dataframe
df_merge = pd.merge(food_db, demo_df, how='left', on='State')
df_merge.head()
# Out:
#                  address                    city  latitude  longitude  \
# 0            324 Main St                 Massena  44.92130  -74.89021
# 1        530 Clinton Ave  Washington Court House  39.53255  -83.44526
# 2   408 Market Square Dr               Maysville  38.62736  -83.79141
# 3  6098 State Highway 37                 Massena  44.95008  -74.84553
# 4        139 Columbus Rd                  Athens  39.35155  -82.09728
#
#          restaurant postal_code State  Population Percent Change  population  \
# 0         McDonalds       13662    NY                        0.4    20201249
# 1           Wendy's       43160    OH                        1.3    11799448
# 2  Frisch's Big Boy       41056    KY                        3.0     4505836
# 3         McDonalds       13662    NY                        0.4    20201249
# 4   OMG! Rotisserie       45701    OH                        1.3    11799448
#
#    % age under 5  % age under 18  % age 65 and older  median household income  \
# ...

# %%
#Showing only Florida data
New_df = df_merge.loc[df_merge['State'].isin(['FL'])]
New_df.head()
# Out:
#                    address              city   latitude  longitude  \
# 261  6201 W Colonial Drive           Orlando  28.552592 -81.464927
# 281      18710 S Dixie Hwy             Miami  25.594612 -80.356141
# 531    1840 SW Gatlin Blvd  Port Saint Lucie  27.264207 -80.404501
# 532    1740 SW Gatlin Blvd  Port Saint Lucie  27.264080 -80.401200
# 545      9301 Daniels Pkwy        Fort Myers  26.547327 -81.801590
#
#          restaurant postal_code State  Population Percent Change  population  \
# 261         Krystal       32808    FL                       14.2    21538187
# 281  Pollo Tropical       33157    FL                       14.2    21538187
# 531       Taco Bell       34953    FL                       14.2    21538187
# 532       McDonalds       34953    FL                       14.2    21538187
# 545         Wendy's       33912    FL                       14.2    21538187
#
#      % age under 5  % age under 18  % age 65 and older  \
# ...

# %%
#Showing how many resturant by name in each state
count = food_db.groupby(['State', 'restaurant'])['restaurant'].apply(len)
count = pd.DataFrame(count)
count.head()
# Out:
#                       restaurant
# State restaurant
# AK    Arby's                   3
#       Carl's Jr                1
#       Domino's Pizza           2
#       McDonalds                3
#       Pizza Hut                2

# %%
#Rename columns and resetting index
new_count = count.rename(columns = {'restaurant':'total'})
new_count = new_count.reset_index(level=['restaurant','State'])
new_count.head()
# Out:
#   State      restaurant  total
# 0    AK          Arby's      3
# 1    AK       Carl's Jr      1
# 2    AK  Domino's Pizza      2
# 3    AK       McDonalds      3
# 4    AK       Pizza Hut      2

# %%
#Showing only Florida Data
fl = new_count.loc[new_count['State'].isin(['FL'])]
fl.head()
# Out:
#     State                             restaurant  total
# 251    FL                                    A&W      2
# 252    FL                                 Arby's      7
# 253    FL                                Blimpie      1
# 254    FL                              Bob Evans      1
# 255    FL  Bojangles' Famous Chicken 'n Biscuits      2

# %%
#Showing how many fast food restaurant in each state
total_by_state = new_count.groupby('State')['total'].sum()
total_by_state = total_by_state.reset_index(level=['State'])
total_by_state.head()
# Out:
#   State  total
# 0    AK     14
# 1    AL    236
# 2    AR    151
# 3    AZ    208
# 4    CA    676

# %%
#Merging dataframe
df_merge2 = pd.merge(total_by_state, demo_df, how='left', on='State')
df_merge2.head()
# Out:
#   State  total  Population Percent Change  population  % age under 5  \
# 0    AK     14                        3.0      733391            7.0
# 1    AL    236                        2.6     5024279            6.0
# 2    AR    151                        3.5     3011524            6.2
# 3    AZ    208                       13.9     7151502            5.9
# 4    CA    676                        6.1    39538223            6.0
#
#    % age under 18  % age 65 and older  median household income  \
# 0            24.6                12.5                    77640
# 1            22.2                17.3                    50536
# 2            23.2                17.4                    47597
# 3            22.5                18.0                    58945
# 4            22.5                14.8                    75235
#
#    per capita income  population per square mile
# 0              36787                         1.2
# 1              27928                        94.4
# ...

# %%
#Adding percentage columns
df_merge2['Percentage(total/population)'] = round(((df_merge2['total'] / df_merge2['population']) * 100),4)
df_merge2.head()
# Out:
#   State  total  Population Percent Change  population  % age under 5  \
# 0    AK     14                        3.0      733391            7.0
# 1    AL    236                        2.6     5024279            6.0
# 2    AR    151                        3.5     3011524            6.2
# 3    AZ    208                       13.9     7151502            5.9
# 4    CA    676                        6.1    39538223            6.0
#
#    % age under 18  % age 65 and older  median household income  \
# 0            24.6                12.5                    77640
# 1            22.2                17.3                    50536
# 2            23.2                17.4                    47597
# 3            22.5                18.0                    58945
# 4            22.5                14.8                    75235
#
#    per capita income  population per square mile  Percentage(total/population)
# 0              36787                         1.2                        0.0019
# ...

# %%
#Calculating average median household income
avg = df_merge2['median household income'].mean()
avg
# Out:
# 63097.86274509804

# %%
#Defining a function to create linear regression plots
def linear_regression(x_value, y_value, text_location, size):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
    regress_value = x_value*slope + intercept
    correlation = st.pearsonr(x_value, y_value)
    print(f"The r-value is: {round(correlation[0],2)}")
    line = f"y = {round(slope,2)}x + {round(intercept,2)}"
    plt.scatter(x_value, y_value)
    plt.plot(x_value, regress_value, c="red")
    plt.annotate(line, text_location, fontsize = size, color = 'red')
    plt.grid()
    plt.show()
    return plt.show()

# %%
# Graph the total population for each state
#Q1
plot2 = df_merge2.sort_values('population', ascending=True).plot.bar(y='population', x='State', figsize=(12,6), rot=90)
plt.xlabel('State')
plt.ylabel('Population')
plt.title('Total Population in Each State')
fig1 = plt.gcf()
plt.draw()
plt.show()
fig1.savefig('Output/q1a.png')

# %%
# Graph the total number of restaurants on each state
#Q1
plot3 = df_merge2.sort_values('total', ascending=True).plot.bar(y='total', x='State', figsize=(12,6), rot=90)
plt.xlabel('State')
plt.ylabel('Total Fast Food Restaurant')
plt.title('Total Fast Food Restaurant in Each State')
fig2 = plt.gcf()
plt.draw()
plt.show()
fig2.savefig('Output/q1b.png')

# %%
# Show the correlation between the total population of a state to the total number of fast food restaurants. 
#Q1
x = df_merge2['total']
y = df_merge2['population']
plt.title('Population vs. Total Fast Food Restaurant per State')
plt.xlabel('Total Fast Food Restaurant')
plt.ylabel('Population')
fig3 = plt.gcf()
plt.draw()
linear_regression(x, y, (400, 0), 10)
fig3.savefig('Output/q1c.png')
# Out:
# The r-value is: 0.86

# %%
# Show the population percentage change for each state
#Q2
plot1 = df_merge2.sort_values('Population Percent Change', ascending=True).plot.bar(y='Population Percent Change',
                                                                                    x='State', figsize=(12,6), rot=90)
plt.xlabel('State')
plt.ylabel('Percentage Change')
plt.axhline(y=0, color='r', linestyle='-')
plt.title('Percentage Change in Each State')
fig4 = plt.gcf()
plt.draw()
plt.show()
fig4.savefig('Output/q2a.png')

# %%
# Show the percentage of fast food restaurants for each state based on the population 
#Q2
plot2 = df_merge2.sort_values('Percentage(total/population)', ascending=True).plot.bar(y='Percentage(total/population)', 
                                                                     x='State', figsize=(12,6), rot=90)
plt.xlabel('State')
plt.ylabel('Percentage')
plt.title('Percentage in Each State')
fig5 = plt.gcf()
plt.show()
fig5.savefig('Output/q2b.png')

# %%
# Show correlation between the media household income and the population of each state
#Q3
x = df_merge2['median household income']
y = df_merge2['population']
plt.title('Median Household Income vs. Population')
plt.xlabel('Median Household Income')
plt.ylabel('Population')
fig6 = plt.gcf()
plt.draw()
linear_regression(x, y, (70000, 30000000), 10)
fig6.savefig('Output/q3a.png')
# Out:
# The r-value is: 0.08

# %%
# Show the Median household income for each state
#Q3
plot1 = df_merge2.sort_values('median household income', ascending=True).plot.bar(y='median household income',
                                                                                    x='State', figsize=(12,6), rot=90)
plt.xlabel('State')
plt.ylabel('Median Household Income')
plt.axhline(y=avg, color='r', linestyle='-')
plt.title('Median Household Income Each State')
fig7 = plt.gcf()
plt.draw()
plt.show()
fig7.savefig('Output/q3b.png')

# %%
#Show the correlation between the median household income and the total number of fast food restaurants for each state
#Q3
x = df_merge2['median household income']
y = df_merge2['total']
plt.title('Median Household Income vs. Total Number of Restaurants')
plt.xlabel('Median Household Income')
plt.ylabel('Total Number of Restaurants')
fig8 = plt.gcf()
plt.draw()
linear_regression(x, y, (70000, 30000000), 10)
fig8.savefig('Output/q3c.png')
# Out:
# The r-value is: -0.18

# %%
#Set parameters for the type of place 
filter = "place:5152ef2577281055c05902b4520b73743e40f00101f901e1d0010000000000c0020692030b54616c6c61686173736565"
categories = "education.college,education.university"
params = {
    "categories":categories,
    "filter":filter,
    "apiKey":geoapify_key,
    "limit":100
}
base_url = "https://api.geoapify.com/v2/places"

# run a request using our params dictionary
response = requests.get(base_url, params=params)
school_data = response.json()
pprint(school_data)
# Out:
# {'features': [{'geometry': {'coordinates': [-84.29874397781273,
#                                             30.441952380506013],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Florida State University',
#                               'address_line2': '600 West College Avenue, '
#                                                'Tallahassee, FL 32301, United '
#                                                'States of America',
#                               'categories': ['education',
#                                              'education.university',
#                                              'internet_access',
#                                              'wheelchair',
#                                              'wheelchair.limited'],
#                               'city': 'Tallahassee',
#                               'country': 'United States',
#                               'country_code': 'us',
# ...

# %%
#Converting json to Dataframe
df = pd.json_normalize(school_data['features'])
# output = df.to_csv('Output/api.csv', index=False)
# output

# %%
#Copying columns from original json Dataframe
df2 = df[['properties.name','properties.lon','properties.lat','properties.address_line2']].copy()
df2 = df2.dropna()
df2
# Out:
#                                   properties.name  properties.lon  \
# 0                        Florida State University      -84.297479
# 1                        Lively Technical College      -84.340059
# 2  Florida Agricultural and Mechanical University      -84.287599
# 3                   Tallahassee Community College      -84.341048
# 4                             FSU Innovation Park      -84.315280
# 5                                   Carnaghi Arts      -84.323862
# 6                         ITT Technical Institute      -84.296818
#
#    properties.lat                           properties.address_line2
# 0       30.442360  600 West College Avenue, Tallahassee, FL 32301...
# 1       30.449345  500 Appleyard Drive, Tallahassee, FL 32304, Un...
# 2       30.422742  1601 West Palmer Avenue, Tallahassee, FL 32307...
# 3       30.442921  444 Appleyard Drive, Tallahassee, FL 32304, Un...
# 4       30.422622  Hernando Drive, Tallahassee, FL 32304, United ...
# ...

# %%
#Create empty dataframe 
school = pd.DataFrame(columns = ['Lat','Lng','Name', 'Address'])
school
# Out:
# Empty DataFrame
# Columns: [Lat, Lng, Name, Address]
# Index: []

# %%
#Loop and add data from json to dataframe()
filter = "place:5152ef2577281055c05902b4520b73743e40f00101f901e1d0010000000000c0020692030b54616c6c61686173736565"
categories = "education.college,education.university"
params = {
    "categories":categories,
    "filter":filter,
    "apiKey":geoapify_key,
    "limit":100
}
base_url = "https://api.geoapify.com/v2/places"

df = pd.json_normalize(school_data['features'])
response = requests.get(base_url, params=params)
school_data = response.json()
print("Starting University/College search")
i=0
for x in school_data["features"]:
    
    try:
        school.loc[i, 'Name'] = x["properties"]["datasource"]['raw']['name']
        school.loc[i, 'Lat'] = x["properties"]["lat"]
        school.loc[i, 'Lng'] = x["properties"]["lon"]
        school.loc[i, 'Address'] = x["properties"]["address_line2"]
    except (KeyError, IndexError):
        school.loc[x, 'Name'] = "No school found"
        
    i+=1
school
# Out:
# Starting University/College search
#          Lat        Lng                                            Name  \
# 0   30.44236 -84.297479                        Florida State University
# 1  30.449345 -84.340059                        Lively Technical College
# 2  30.422742 -84.287599  Florida Agricultural and Mechanical University
# 3  30.442921 -84.341048                   Tallahassee Community College
# 4  30.422622  -84.31528                             FSU Innovation Park
# 5  30.438746 -84.323862                                   Carnaghi Arts
# 6  30.477246 -84.296818                         ITT Technical Institute
#
#                                              Address
# 0  600 West College Avenue, Tallahassee, FL 32301...
# 1  500 Appleyard Drive, Tallahassee, FL 32304, Un...
# 2  1601 West Palmer Avenue, Tallahassee, FL 32307...
# 3  444 Appleyard Drive, Tallahassee, FL 32304, Un...
# 4  Hernando Drive, Tallahassee, FL 32304, United ...
# ...

# %%
#Set parameters for the type of place 
filter = "place:51d3cf3ad1605854c059363f07e168193a40f00101f9015179120000000000c0020992030e436f6c6c69657220436f756e7479"
categories = "accommodation.hotel"
params = {
    "categories":categories,
    "filter":filter,
    "apiKey":geoapify_key,
    "limit":100
}
base_url = "https://api.geoapify.com/v2/places"

# run a request using our params dictionary
response1 = requests.get(base_url, params=params)
hotel_data = response1.json()
pprint(hotel_data)
# Out:
# {'features': [{'geometry': {'coordinates': [-81.51077620411306,
#                                             25.958585864291976],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Port of the Islands - '
#                                                'Everglades Adventure Resort',
#                               'address_line2': '25000 Tamiami Trail, Collier '
#                                                'County, FL 34114, United '
#                                                'States of America',
#                               'categories': ['accommodation',
#                                              'accommodation.hotel',
#                                              'building',
#                                              'building.accommodation'],
#                               'country': 'United States',
#                               'country_code': 'us',
# ...

# %%
#Converting json to Dataframe
df1 = pd.json_normalize(hotel_data['features'])
df1.head()
# Out:
#       type                                    properties.name  \
# 0  Feature  Port of the Islands - Everglades Adventure Resort
# 1  Feature                                       Best Western
# 2  Feature                                 Bayview Villas LLC
# 3  Feature                               Gulfcoast Inn Naples
# 4  Feature              JW Marriott Marco Island Beach Resort
#
#   properties.country properties.country_code properties.state  \
# 0      United States                      us          Florida
# 1      United States                      us          Florida
# 2      United States                      us          Florida
# 3      United States                      us          Florida
# 4      United States                      us          Florida
#
#   properties.county properties.postcode        properties.street  \
# 0    Collier County               34114            Tamiami Trail
# 1    Collier County               34105             Dudley Drive
# ...

# %%
#Copying columns from original json Dataframe
df3 = df1[['properties.name','properties.lon','properties.lat','properties.address_line2']].copy()
df3 = df3.dropna()
df3
# Out:
#                                       properties.name  properties.lon  \
# 0   Port of the Islands - Everglades Adventure Resort      -81.510800
# 1                                        Best Western      -81.739174
# 2                                  Bayview Villas LLC      -81.509004
# 3                                Gulfcoast Inn Naples      -81.800804
# 4               JW Marriott Marco Island Beach Resort      -81.729367
# ..                                                ...             ...
# 73                            Fifth Avenue Beach Club      -81.804794
# 74                                         Inn on 5th      -81.797858
# 75                              Inn on 5th Club Level      -81.797840
# 76                                     The Ivey House      -81.384025
# 79                         Naples Grande Beach Resort      -81.810364
#
#     properties.lat                           properties.address_line2
# ...

# %%
#Displaying map of all fast food restaurants
map_plot_1 = df_merge.hvplot.points(
    "longitude",
    "latitude",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    color = "restaurant",
    hover_cols=['State','population']
    
)
map_plot_1
# Out:
# C:\Users\andre\anaconda3\envs\dev\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [longitude,latitude]   (restaurant,State,population)

# %%
#Displaying map of current Florida fast food restaurants
map_plot_2 = New_df.hvplot.points(
    "longitude",
    "latitude",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    color = "restaurant",
    hover_cols=['population']
    
)
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [longitude,latitude]   (restaurant,population)

# %%
#Displaying map of recommend place to open up a new fast food restaurant near college/universities(Tallahassee)
map_plot_3 = df2.hvplot.points(
    "properties.lon",
    "properties.lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    color = "properties.name",
    size = 100
)
map_plot_3
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [properties.lon,properties.lat]   (properties.name)

# %%
#Displaying map of recommend place to open up a new fast food restaurant near hotel (Naples)
map_plot_4 = df3.hvplot.points(
    "properties.lon",
    "properties.lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    color = "properties.name",
    size = 50
)
map_plot_4
